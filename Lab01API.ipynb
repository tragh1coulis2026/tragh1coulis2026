# %% [markdown]
# <a href="https://colab.research.google.com/github/tragh1coulis2026/tragh1coulis2026/blob/main/Lab01API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests

# %%
import json

# %%
import requests

# %%
import os

# %%
SERPAPI_API_KEY = "2f4916181bbbe545cf62c3415ccf1d94e7784862aa092508700645494164fdd9"

# %%
params = {
    "api_key": SERPAPI_API_KEY,
    "engine": "youtube_video_transcript",
    "v": "wpSqsVHXGIA",
    "type": "asr"
}

# %%
search = requests.get("https://serpapi.com/search", params=params)
response = search.json()

print(json.dumps(response, indent=2))
# Out:
# {
#   "search_metadata": {
#     "id": "698e86c0998aadc72665e890",
#     "status": "Success",
#     "json_endpoint": "https://serpapi.com/searches/VhDwNIdSxXeClpmBWTEZFQ/698e86c0998aadc72665e890.json",
#     "created_at": "2026-02-13 02:04:48 UTC",
#     "processed_at": "2026-02-13 02:04:48 UTC",
#     "youtube_video_transcript_url": "https://www.youtube.com/watch?v=wpSqsVHXGIA",
#     "raw_html_file": "https://serpapi.com/searches/VhDwNIdSxXeClpmBWTEZFQ/698e86c0998aadc72665e890.html",
#     "prettify_html_file": "https://serpapi.com/searches/VhDwNIdSxXeClpmBWTEZFQ/698e86c0998aadc72665e890.prettify",
#     "total_time_taken": 5.23
#   },
#   "search_parameters": {
#     "engine": "youtube_video_transcript",
#     "v": "wpSqsVHXGIA",
#     "language_code": "en",
#     "type": "asr"
#   },
#   "transcript": [
#     {
#       "start_ms": 80,
#       "end_ms": 1839,
#       "snippet": "Say hello to our YouTube transcripts",
#       "start_time_text": "0:00"
#     },
#     {
# ...

# %%
for result in response.get("transcript", []):
  snippet = result.get("snippet")
  start_time_text = result.get("start_time_text")

  print(f"SnippetL: {snippet}")
  print(f"Start_Time: {start_time_text}")
  print("-" * 10)
# Out:
# SnippetL: Say hello to our YouTube transcripts
# Start_Time: 0:00
# ----------
# SnippetL: API. A simple way to scrape video
# Start_Time: 0:01
# ----------
# SnippetL: transcripts instantly. Hi, it's Hilman
# Start_Time: 0:04
# ----------
# SnippetL: from SER API. Let's see how to scrape
# Start_Time: 0:06
# ----------
# SnippetL: YouTube transcript using a simple API
# Start_Time: 0:09
# ----------
# SnippetL: from SER API. Make sure you've
# Start_Time: 0:11
# ----------
# SnippetL: registered at SER API.com to get your
# Start_Time: 0:13
# ----------
# SnippetL: SER API key. Next, we want to export our
# Start_Time: 0:16
# ----------
# SnippetL: SER API API key. Make sure to replace
# Start_Time: 0:19
# ----------
# SnippetL: your actual API key that you get from
# Start_Time: 0:22
# ----------
# SnippetL: our dashboard. Next, create a new
# Start_Time: 0:24
# ----------
# SnippetL: main.py PI file on the same folder we
# Start_Time: 0:27
# ----------
# ...

# %%
with open('transcript.txt', 'w') as f:
  for result in response.get("transcript", []):
    snippet = result.get("snippet")
   if snippet:
    f.write(f"{snippet}\n)")

    print("Results saved to transcript.txt")
# Out:
#   File "<tokenize>", line 4
#     if snippet:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
with open('transcript.txt', 'w') as f:
  for result in response.get("transcript", []):
    snippet = result.get("snippet")
    if snippet:
      f.write(f"{snippet}\n")

      print("Results saved to transcript.txt")
# Out:
# Results saved to transcript.txt
# Results saved to transcript.txt
# Results saved to transcript.txt
# Results saved to transcript.txt
# Results saved to transcript.txt
# Results saved to transcript.txt
# Results saved to transcript.txt
# Results saved to transcript.txt
# Results saved to transcript.txt
# Results saved to transcript.txt
# Results saved to transcript.txt
# Results saved to transcript.txt
# Results saved to transcript.txt
# Results saved to transcript.txt
# Results saved to transcript.txt
# Results saved to transcript.txt
# Results saved to transcript.txt
# Results saved to transcript.txt
# Results saved to transcript.txt
# Results saved to transcript.txt
# Results saved to transcript.txt
# Results saved to transcript.txt
# Results saved to transcript.txt
# Results saved to transcript.txt
# Results saved to transcript.txt
# Results saved to transcript.txt
# Results saved to transcript.txt
# Results saved to transcript.txt
# Results saved to transcript.txt
# ...
