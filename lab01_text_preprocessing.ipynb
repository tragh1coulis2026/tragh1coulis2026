# %% [markdown]
# <a href="https://colab.research.google.com/github/tragh1coulis2026/tragh1coulis2026/blob/main/lab01_text_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests

# %%
import json

# %%
import requests

# %%
import os

# %%
SERPAPI_API_KEY = "2f4916181bbbe545cf62c3415ccf1d94e7784862"

# %%
params = {
    "api_key": SERPAPI_API_KEY,
    "engine": "youtube_video_transcript",
    "v": "wpSqsVHXGIA",
    "type": "asr"
}
